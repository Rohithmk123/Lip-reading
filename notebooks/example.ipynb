# %% [markdown]
# # Silent-interpreter Example Notebook
#
# This notebook demonstrates basic usage of the Silent-interpreter project.

# %%
# Import basic libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Example: create and plot simple data
data = np.random.randn(100)
plt.hist(data, bins=20)
plt.title('Random Data')
plt.show()
